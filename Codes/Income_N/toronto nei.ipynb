# %% [markdown]
# # Toronto Neighbourhoods and Income of Individuals

# %% [markdown]
# The Open data porta was used to obtain the data of Neighbourhoods in Toronto city of Ontario.

# %%
# 3rd party imports
import os
import json
import pandas as pd
import seaborn as sns
from datetime import datetime
import matplotlib.pylab as plt
from bs4 import BeautifulSoup
#!pip install pandas openpyxl


# Configure Notebook
# %matplotlib inline
plt.style.use('fivethirtyeight')
sns.set_context("notebook")
import warnings
warnings.filterwarnings('ignore')
# %config Completer.use_jedi = False

# %% [markdown]
# ### The main csv was obtained and loaded in the file.

# %%
assignment_files = os.listdir()

# Print the contents of the directory
#print(assignment_files)

# %%
# Load the csv. 
tn_df = pd.read_csv("Toronto-Neigh.csv", encoding='Windows-1252')
tnT_df=tn_df.T

# View DataFrame
tnT_df.head()
# Out:
#                                                    0     \
# Neighbourhood Name                 Neighbourhood Number
# West Humber-Clairville                                1
# Mount Olive-Silverstone-Jamestown                     2
# Thistletown-Beaumond Heights                          3
# Rexdale-Kipling                                       4
#
#                                                                    1     \
# Neighbourhood Name                                TSNS 2020 Designation
# West Humber-Clairville             Not an NIA or Emerging Neighbourhood
# Mount Olive-Silverstone-Jamestown        Neighbourhood Improvement Area
# Thistletown-Beaumond Heights             Neighbourhood Improvement Area
# Rexdale-Kipling                    Not an NIA or Emerging Neighbourhood
#
#                                                                                 2     \
# Neighbourhood Name                 Total - Age groups of the population - 25% sam...
# West Humber-Clairville                                                         33300
# Mount Olive-Silverstone-Jamestown                                              31345
# Thistletown-Beaumond Heights                                                    9850
# Rexdale-Kipling                                                                10375
#
#                                               3                 4     \
# Neighbourhood Name                   0 to 14 years      0 to 4 years
# West Humber-Clairville                        4295              1460
# Mount Olive-Silverstone-Jamestown             5690              1650
# Thistletown-Beaumond Heights                  1495               505
# Rexdale-Kipling                               1575               505
#
#                                                5                   6     \
# Neighbourhood Name                     5 to 9 years      10 to 14 years
# West Humber-Clairville                         1345                1485
# Mount Olive-Silverstone-Jamestown              1860                2175
# Thistletown-Beaumond Heights                    540                 455
# Rexdale-Kipling                                 615                 455
#
#                                                7                   8     \
# Neighbourhood Name                   15 to 64 years      15 to 19 years
# West Humber-Clairville                        23640                1860
# Mount Olive-Silverstone-Jamestown             21490                2280
# Thistletown-Beaumond Heights                   6615                 570
# Rexdale-Kipling                                6950                 515
#
#                                                  9     ...  \
# Neighbourhood Name                     20 to 24 years  ...
# West Humber-Clairville                           3175  ...
# Mount Olive-Silverstone-Jamestown                2675  ...
# Thistletown-Beaumond Heights                      745  ...
# Rexdale-Kipling                                   715  ...
#
#                                                               2593  \
# Neighbourhood Name                   Between 9 a.m. and 11:59 a.m.
# West Humber-Clairville                                        1665
# Mount Olive-Silverstone-Jamestown                             1145
# Thistletown-Beaumond Heights                                   395
# Rexdale-Kipling                                                425
#
#                                                               2594  \
# Neighbourhood Name                   Between 12 p.m. and 4:59 a.m.
# West Humber-Clairville                                        2935
# Mount Olive-Silverstone-Jamestown                             2965
# Thistletown-Beaumond Heights                                   635
# Rexdale-Kipling                                                775
#
#                                                                                 2595  \
# Neighbourhood Name                 Total - Eligibility for instruction in the min...
# West Humber-Clairville                                                          5430
# Mount Olive-Silverstone-Jamestown                                               7285
# Thistletown-Beaumond Heights                                                    1860
# Rexdale-Kipling                                                                 1910
#
#                                                                                 2596  \
# Neighbourhood Name                   Children eligible for instruction in the min...
# West Humber-Clairville                                                           410
# Mount Olive-Silverstone-Jamestown                                                510
# Thistletown-Beaumond Heights                                                     180
# Rexdale-Kipling                                                                  135
#
#                                                                                 2597  \
# Neighbourhood Name                   Children not eligible for instruction in the...
# West Humber-Clairville                                                          5020
# Mount Olive-Silverstone-Jamestown                                               6780
# Thistletown-Beaumond Heights                                                    1685
# Rexdale-Kipling                                                                 1770
#
#                                                                                 2598  \
# Neighbourhood Name                 Total - Eligibility and instruction in the min...
# West Humber-Clairville                                                          3875
# Mount Olive-Silverstone-Jamestown                                               5540
# Thistletown-Beaumond Heights                                                    1325
# Rexdale-Kipling                                                                 1370
#
#                                                                                 2599  \
# Neighbourhood Name                   Children eligible for instruction in the min...
# West Humber-Clairville                                                           335
# Mount Olive-Silverstone-Jamestown                                                395
# Thistletown-Beaumond Heights                                                     120
# Rexdale-Kipling                                                                   90
#
#                                                                                 2600  \
# Neighbourhood Name                     Eligible children who have been instructed...
# West Humber-Clairville                                                           255
# Mount Olive-Silverstone-Jamestown                                                245
# Thistletown-Beaumond Heights                                                      75
# Rexdale-Kipling                                                                   75
#
#                                                                                 2601  \
# Neighbourhood Name                     Eligible children who have not been instru...
# West Humber-Clairville                                                            75
# Mount Olive-Silverstone-Jamestown                                                145
# Thistletown-Beaumond Heights                                                      45
# Rexdale-Kipling                                                                   25
#
#                                                                                 2602
# Neighbourhood Name                   Children not eligible for instruction in the...
# West Humber-Clairville                                                          3540
# Mount Olive-Silverstone-Jamestown                                               5145
# Thistletown-Beaumond Heights                                                    1205
# Rexdale-Kipling                                                                 1275
#
# [5 rows x 2603 columns]

# %% [markdown]
# ## Filtering and Cleaning the dataframe to obtain the required data set.

# %% [markdown]
# The index of the required data was obtained by searching for the keywords.

# %%
# Extract the first data row (index 1, which is the second row of the sheet)
first_row = tn_df.T.iloc[0].astype(str)

# Keywords to search for
keywords = [
    'Income statistics in 2020 for the population aged 15 years and over in private households - 25% sample data',
   # 'Income', 
    'tax',
    'after-tax income',
    'after-tax income in 2020',
    'Median total income'
]

# Initialize a dictionary to store all indexes for each keyword
all_keyword_indexes = {}

# Find keywords in the first row (case-insensitive matching) and their corresponding indexes
for keyword in keywords:
    # Find all indexes for the keyword
    indexes = first_row[first_row.str.contains(keyword, case=False, na=False)].index.tolist()
    
    # If keyword is found, store the indexes
    if indexes:
        # Store the indexes for the keyword
        all_keyword_indexes[keyword] = indexes
        
        # Calculate and print only the min and max indexes
        min_index = min(indexes)  # Get the minimum index
        max_index = max(indexes)  # Get the maximum index
        print(f"Keyword '{keyword}' found at min index: {min_index} and max index: {max_index}")

# At this point, the full list of indexes is saved in the all_keyword_indexes dictionary.
# Out:
# Keyword 'Income statistics in 2020 for the population aged 15 years and over in private households - 25% sample data' found at min index: 60 and max index: 1949
# Keyword 'tax' found at min index: 64 and max index: 424
# Keyword 'after-tax income' found at min index: 64 and max index: 424
# Keyword 'after-tax income in 2020' found at min index: 65 and max index: 166
# Keyword 'Median total income' found at min index: 62 and max index: 421

# %%
# Access the actual values at various index to confirm the result.

value_at_index_60 = tn_df.T.iloc[0,92]  
value_at_index_1949 = tn_df.T.iloc[0, 424]  

# Optionally, get the column names at those indices
column_name_60 = tn_df.T.columns[92]  
column_name_1949 = tn_df.T.columns[424]  

# Print the results
print(f"Value at column {column_name_60}: {value_at_index_60}")
print(f"Value at column {column_name_1949} : {value_at_index_1949}")
# Out:
# Value at column 92:     Under $10,000 (including loss)
# Value at column 424 :   Average after-tax income of one-parent economic family in 2020 ($)

# %% [markdown]
# ## Extracting the desired columns

# %%
# Step 1: Extract the first column (assuming it contains labels or identifiers)
first_column = tn_df.T.iloc[:, 0]

# Step 2: Filter the columns based on index range (between 60 and 168)
filtered_columns = tn_df.T.iloc[:, 60:167]  # Select columns from index 60 to 168 (inclusive of 60, exclusive of 169)

# Step 3: Create a new DataFrame with the first column and the filtered columns
filtered_df = pd.concat([first_column, filtered_columns], axis=1)

# Step 4: Print the resulting filtered DataFrame
(filtered_df)
# Out:
#                                                     0    \
# Neighbourhood Name                 Neighbourhood Number
# West Humber-Clairville                                1
# Mount Olive-Silverstone-Jamestown                     2
# Thistletown-Beaumond Heights                          3
# Rexdale-Kipling                                       4
# ...                                                 ...
# Yonge-Bay Corridor                                  170
# Junction-Wallace Emerson                            171
# Dovercourt Village                                  172
# North Toronto                                       173
# South Eglinton-Davisville                           174
#
#                                                                                  60   \
# Neighbourhood Name                 Total - Income statistics in 2020 for the popu...
# West Humber-Clairville                                                         29000
# Mount Olive-Silverstone-Jamestown                                              25660
# Thistletown-Beaumond Heights                                                    8355
# Rexdale-Kipling                                                                 8800
# ...                                                                              ...
# Yonge-Bay Corridor                                                             11680
# Junction-Wallace Emerson                                                       20100
# Dovercourt Village                                                             11015
# North Toronto                                                                  14570
# South Eglinton-Davisville                                                      20545
#
#                                                                                  61   \
# Neighbourhood Name                   Number of total income recipients aged 15 ye...
# West Humber-Clairville                                                         27555
# Mount Olive-Silverstone-Jamestown                                              23990
# Thistletown-Beaumond Heights                                                    7910
# Rexdale-Kipling                                                                 8445
# ...                                                                              ...
# Yonge-Bay Corridor                                                             10930
# Junction-Wallace Emerson                                                       19420
# Dovercourt Village                                                             10600
# North Toronto                                                                  13865
# South Eglinton-Davisville                                                      19760
#
#                                                                                  62   \
# Neighbourhood Name                     Median total income in 2020  among recipie...
# West Humber-Clairville                                                         33600
# Mount Olive-Silverstone-Jamestown                                              29600
# Thistletown-Beaumond Heights                                                   32800
# Rexdale-Kipling                                                                33600
# ...                                                                              ...
# Yonge-Bay Corridor                                                             44000
# Junction-Wallace Emerson                                                       41200
# Dovercourt Village                                                             38000
# North Toronto                                                                  46000
# South Eglinton-Davisville                                                      52400
#
#                                                                                  63   \
# Neighbourhood Name                     Average total income in 2020 among recipie...
# West Humber-Clairville                                                         40560
# Mount Olive-Silverstone-Jamestown                                              35000
# Thistletown-Beaumond Heights                                                   41520
# Rexdale-Kipling                                                                42040
# ...                                                                              ...
# Yonge-Bay Corridor                                                             68200
# Junction-Wallace Emerson                                                       54350
# Dovercourt Village                                                             55850
# North Toronto                                                                  58100
# South Eglinton-Davisville                                                      69000
#
#                                                                                  64   \
# Neighbourhood Name                   Number of after-tax income recipients aged 1...
# West Humber-Clairville                                                         27570
# Mount Olive-Silverstone-Jamestown                                              23995
# Thistletown-Beaumond Heights                                                    7925
# Rexdale-Kipling                                                                 8470
# ...                                                                              ...
# Yonge-Bay Corridor                                                             10930
# Junction-Wallace Emerson                                                       19420
# Dovercourt Village                                                             10600
# North Toronto                                                                  13865
# South Eglinton-Davisville                                                      19795
#
#                                                                                  65   \
# Neighbourhood Name                     Median after-tax income in 2020 among reci...
# West Humber-Clairville                                                         31600
# Mount Olive-Silverstone-Jamestown                                              28400
# Thistletown-Beaumond Heights                                                   30600
# Rexdale-Kipling                                                                31800
# ...                                                                              ...
# Yonge-Bay Corridor                                                             40400
# Junction-Wallace Emerson                                                       37200
# Dovercourt Village                                                             34800
# North Toronto                                                                  41200
# South Eglinton-Davisville                                                      46000
#
#                                                                                  66   \
# Neighbourhood Name                     Average after-tax income in 2020 among rec...
# West Humber-Clairville                                                         35800
# Mount Olive-Silverstone-Jamestown                                              31760
# Thistletown-Beaumond Heights                                                   36360
# Rexdale-Kipling                                                                36880
# ...                                                                              ...
# Yonge-Bay Corridor                                                             53050
# Junction-Wallace Emerson                                                       45480
# Dovercourt Village                                                             46200
# North Toronto                                                                  48200
# South Eglinton-Davisville                                                      54700
#
#                                                                                  67   \
# Neighbourhood Name                   Number of market income recipients aged 15 y...
# West Humber-Clairville                                                         23565
# Mount Olive-Silverstone-Jamestown                                              18275
# Thistletown-Beaumond Heights                                                    6450
# Rexdale-Kipling                                                                 7010
# ...                                                                              ...
# Yonge-Bay Corridor                                                              9985
# Junction-Wallace Emerson                                                       16950
# Dovercourt Village                                                              9525
# North Toronto                                                                  12585
# South Eglinton-Davisville                                                      18115
#
#                                                                                  68   \
# Neighbourhood Name                     Median market income in 2020  among recipi...
# West Humber-Clairville                                                         26400
# Mount Olive-Silverstone-Jamestown                                              22200
# Thistletown-Beaumond Heights                                                   25800
# Rexdale-Kipling                                                                28400
# ...                                                                              ...
# Yonge-Bay Corridor                                                             44000
# Junction-Wallace Emerson                                                       39600
# Dovercourt Village                                                             33600
# North Toronto                                                                  44400
# South Eglinton-Davisville                                                      51600
#
#                                    ...  \
# Neighbourhood Name                 ...
# West Humber-Clairville             ...
# Mount Olive-Silverstone-Jamestown  ...
# Thistletown-Beaumond Heights       ...
# Rexdale-Kipling                    ...
# ...                                ...
# Yonge-Bay Corridor                 ...
# Junction-Wallace Emerson           ...
# Dovercourt Village                 ...
# North Toronto                      ...
# South Eglinton-Davisville          ...
#
#                                                                                  157  \
# Neighbourhood Name                 Composition of total income in 2019 of the pop...
# West Humber-Clairville                                                           100
# Mount Olive-Silverstone-Jamestown                                                100
# Thistletown-Beaumond Heights                                                     100
# Rexdale-Kipling                                                                  100
# ...                                                                              ...
# Yonge-Bay Corridor                                                               100
# Junction-Wallace Emerson                                                         100
# Dovercourt Village                                                               100
# North Toronto                                                                    100
# South Eglinton-Davisville                                                        100
#
#                                                    158  \
# Neighbourhood Name                   Market income (%)
# West Humber-Clairville                            83.8
# Mount Olive-Silverstone-Jamestown                 77.2
# Thistletown-Beaumond Heights                        82
# Rexdale-Kipling                                   82.2
# ...                                                ...
# Yonge-Bay Corridor                                96.4
# Junction-Wallace Emerson                            90
# Dovercourt Village                                90.4
# North Toronto                                     92.8
# South Eglinton-Davisville                           94
#
#                                                          159  \
# Neighbourhood Name                     Employment income (%)
# West Humber-Clairville                                    75
# Mount Olive-Silverstone-Jamestown                       70.8
# Thistletown-Beaumond Heights                            71.6
# Rexdale-Kipling                                         72.2
# ...                                                      ...
# Yonge-Bay Corridor                                      81.6
# Junction-Wallace Emerson                                83.2
# Dovercourt Village                                      81.2
# North Toronto                                           81.6
# South Eglinton-Davisville                               78.8
#
#                                                           160  \
# Neighbourhood Name                   Government transfers (%)
# West Humber-Clairville                                   16.2
# Mount Olive-Silverstone-Jamestown                        22.8
# Thistletown-Beaumond Heights                               18
# Rexdale-Kipling                                          17.9
# ...                                                       ...
# Yonge-Bay Corridor                                        3.7
# Junction-Wallace Emerson                                 10.1
# Dovercourt Village                                        9.5
# North Toronto                                             7.3
# South Eglinton-Davisville                                 5.9
#
#                                                                      161  \
# Neighbourhood Name                     Employment insurance benefits (%)
# West Humber-Clairville                                               1.4
# Mount Olive-Silverstone-Jamestown                                    1.5
# Thistletown-Beaumond Heights                                         1.6
# Rexdale-Kipling                                                        1
# ...                                                                  ...
# Yonge-Bay Corridor                                                   0.4
# Junction-Wallace Emerson                                             0.9
# Dovercourt Village                                                   0.7
# North Toronto                                                        0.6
# South Eglinton-Davisville                                            0.6
#
#                                                                                  162  \
# Neighbourhood Name                 Total - Income statistics for persons aged 15 ...
# West Humber-Clairville                                                          4990
# Mount Olive-Silverstone-Jamestown                                               3530
# Thistletown-Beaumond Heights                                                    1320
# Rexdale-Kipling                                                                 1715
# ...                                                                              ...
# Yonge-Bay Corridor                                                              5600
# Junction-Wallace Emerson                                                        5255
# Dovercourt Village                                                              3170
# North Toronto                                                                   5935
# South Eglinton-Davisville                                                       8115
#
#                                                                  163  \
# Neighbourhood Name                   Median total income in 2020 ($)
# West Humber-Clairville                                         30600
# Mount Olive-Silverstone-Jamestown                              28000
# Thistletown-Beaumond Heights                                   32800
# Rexdale-Kipling                                                27400
# ...                                                              ...
# Yonge-Bay Corridor                                             40800
# Junction-Wallace Emerson                                       36800
# Dovercourt Village                                             34400
# North Toronto                                                  48400
# South Eglinton-Davisville                                      53600
#
#                                                                   164  \
# Neighbourhood Name                   Average total income in 2020 ($)
# West Humber-Clairville                                          37040
# Mount Olive-Silverstone-Jamestown                               33920
# Thistletown-Beaumond Heights                                    39300
# Rexdale-Kipling                                                 37040
# ...                                                               ...
# Yonge-Bay Corridor                                              61600
# Junction-Wallace Emerson                                        49640
# Dovercourt Village                                              49080
# North Toronto                                                   59700
# South Eglinton-Davisville                                       67200
#
#                                                                      165  \
# Neighbourhood Name                   Median after-tax income in 2020 ($)
# West Humber-Clairville                                             29200
# Mount Olive-Silverstone-Jamestown                                  27200
# Thistletown-Beaumond Heights                                       30800
# Rexdale-Kipling                                                    26800
# ...                                                                  ...
# Yonge-Bay Corridor                                                 37200
# Junction-Wallace Emerson                                           33600
# Dovercourt Village                                                 31800
# North Toronto                                                      42800
# South Eglinton-Davisville                                          47200
#
#                                                                       166
# Neighbourhood Name                   Average after-tax income in 2020 ($)
# West Humber-Clairville                                              32840
# Mount Olive-Silverstone-Jamestown                                   30480
# Thistletown-Beaumond Heights                                        34700
# Rexdale-Kipling                                                     32960
# ...                                                                   ...
# Yonge-Bay Corridor                                                  48920
# Junction-Wallace Emerson                                            42160
# Dovercourt Village                                                  41560
# North Toronto                                                       49160
# South Eglinton-Davisville                                           53750
#
# [159 rows x 108 columns]

# %%
## Reset the index of the dataframe

# Step 1: Reset the row index and add it as a column 
filtered_df_reset = filtered_df.reset_index()

# Step 2: Set the row index column to the first column (this you already did)
filtered_df_reset.set_index(filtered_df_reset.columns[0], inplace=True)

# Step 3: Reset column headers to default (0, 1, 2, ...)
# This step will reset the column headers (the numeric indices you mentioned)
filtered_df_reset.columns = range(filtered_df_reset.shape[1])

# Confirmation message
print("Row index has been moved to the first column, and column headers have been reset.")
# Out:
# Row index has been moved to the first column, and column headers have been reset.

# %%
## transposing the dataframe.

# Step 1: Store original column names (neighborhood names)
neighborhood_names = filtered_df.columns.tolist()

# Step 2: Reset the row index and add it as a column
filtered_df_reset = filtered_df.reset_index()

# Step 3: Set the row index column to the first column
filtered_df_reset.set_index(filtered_df_reset.columns[0], inplace=True)

# Step 4: Transpose the DataFrame (rows become columns)
filtered_df_transposed = filtered_df_reset.T  # Transpose

# Step 5: Reset the index after transposition (to avoid unwanted row index after transpose)
filtered_df_transposed.reset_index(drop=True, inplace=True)

# Confirmation message
print("Rows have been transformed to columns, the neighborhood names have been preserved.")
# Out:
# Rows have been transformed to columns, the neighborhood names have been preserved.

# %%
#Check the transposed data frame

filtered_df_transposed
# Out:
# index                                 Neighbourhood Name  \
# 0                                   Neighbourhood Number
# 1      Total - Income statistics in 2020 for the popu...
# 2        Number of total income recipients aged 15 ye...
# 3          Median total income in 2020  among recipie...
# 4          Average total income in 2020 among recipie...
# ..                                                   ...
# 103    Total - Income statistics for persons aged 15 ...
# 104                      Median total income in 2020 ($)
# 105                     Average total income in 2020 ($)
# 106                  Median after-tax income in 2020 ($)
# 107                 Average after-tax income in 2020 ($)
#
# index West Humber-Clairville Mount Olive-Silverstone-Jamestown  \
# 0                          1                                 2
# 1                      29000                             25660
# 2                      27555                             23990
# 3                      33600                             29600
# 4                      40560                             35000
# ..                       ...                               ...
# 103                     4990                              3530
# 104                    30600                             28000
# 105                    37040                             33920
# 106                    29200                             27200
# 107                    32840                             30480
#
# index Thistletown-Beaumond Heights Rexdale-Kipling Elms-Old Rexdale  \
# 0                                3               4                5
# 1                             8355            8800             7745
# 2                             7910            8445             7325
# 3                            32800           33600            34400
# 4                            41520           42040            41240
# ..                             ...             ...              ...
# 103                           1320            1715             1000
# 104                          32800           27400            33600
# 105                          39300           37040            40200
# 106                          30800           26800            31200
# 107                          34700           32960            35300
#
# index Kingsview Village-The Westway Willowridge-Martingrove-Richview  \
# 0                                 6                                7
# 1                             18090                            18945
# 2                             17240                            18140
# 3                             34400                            40800
# 4                             44880                            53750
# ..                              ...                              ...
# 103                            3080                             2905
# 104                           34400                            40400
# 105                           44800                            52100
# 106                           32400                            36800
# 107                           38360                            44480
#
# index Humber Heights-Westmount Edenbridge-Humber Valley  ...  \
# 0                            8                        9  ...
# 1                         8635                    13125  ...
# 2                         8305                    12650  ...
# 3                        40400                    48400  ...
# 4                        60900                    98200  ...
# ..                         ...                      ...  ...
# 103                       1525                     2290  ...
# 104                      40800                    50400  ...
# 105                      51200                    65400  ...
# 106                      36400                    44000  ...
# 107                      42680                    52500  ...
#
# index Harbourfront-CityPlace St Lawrence-East Bayfront-The Islands  \
# 0                        165                                   166
# 1                      26065                                 29005
# 2                      24955                                 27980
# 3                      58800                                 58000
# 4                      73100                                 79700
# ..                       ...                                   ...
# 103                    11755                                 12365
# 104                    62400                                 61600
# 105                    73100                                 79800
# 106                    53600                                 52800
# 107                    58150                                 61950
#
# index Church-Wellesley Downtown Yonge East Bay-Cloverhill Yonge-Bay Corridor  \
# 0                  167                 168            169                170
# 1                21420               16645          15925              11680
# 2                20515               15955          15015              10930
# 3                42800               45200          39600              44000
# 4                56700               66700          66300              68200
# ..                 ...                 ...            ...                ...
# 103              11940                8585           8655               5600
# 104              39600               41200          33600              40800
# 105              53800               60550          52700              61600
# 106              36800               37200          32000              37200
# 107              44160               48600          42400              48920
#
# index Junction-Wallace Emerson Dovercourt Village North Toronto  \
# 0                          171                172           173
# 1                        20100              11015         14570
# 2                        19420              10600         13865
# 3                        41200              38000         46000
# 4                        54350              55850         58100
# ..                         ...                ...           ...
# 103                       5255               3170          5935
# 104                      36800              34400         48400
# 105                      49640              49080         59700
# 106                      33600              31800         42800
# 107                      42160              41560         49160
#
# index South Eglinton-Davisville
# 0                           174
# 1                         20545
# 2                         19760
# 3                         52400
# 4                         69000
# ..                          ...
# 103                        8115
# 104                       53600
# 105                       67200
# 106                       47200
# 107                       53750
#
# [108 rows x 159 columns]

# %% [markdown]
# ## Input the other source of neighbourhood-income data

# %%
t_nn = pd.read_csv("toronto_neighborhood_data_filtered.csv")
t_nn
# Out:
#            Neighborhood less than $20,000 Income $20,000 - $39,999  \
# 0               Toronto           108,855                  264,185
# 1     Agincourt/Malvern             1,340                    4,625
# 2        Ajax/Pickering             1,440                    4,975
# 3             Alderwood               120                      525
# 4                Aurora               655                    1,630
# ..                  ...               ...                      ...
# 130    Woodbine-Lumsden               160                      475
# 131            Wychwood               315                      965
# 132      Yonge-Eglinton               350                      725
# 133     Yonge-St. Clair               440                      770
# 134  Yorkdale-Glen Park               355                    1,095
#
#     Income $40,000 - $59,999 Income $60,000 - $79,999  \
# 0                    268,775                  272,180
# 1                      5,225                    5,595
# 2                      6,500                    7,925
# 3                        560                      535
# 4                      2,015                    2,340
# ..                       ...                      ...
# 130                      385                      380
# 131                      735                      650
# 132                      870                      720
# 133                      935                      920
# 134                    1,060                      945
#
#     Income $80,000 - $99,999 Income $100,000 and Over      Total
# 0                    252,230                1,096,245  2,262,475
# 1                      5,050                   16,355     38,190
# 2                      8,105                   43,965     72,910
# 3                        475                    2,565      4,790
# 4                      2,140                   12,730     21,505
# ..                       ...                      ...        ...
# 130                      355                    1,615      3,380
# 131                      640                    2,460      5,770
# 132                      445                    2,875      5,995
# 133                      740                    3,400      7,205
# 134                      790                    2,590      6,835
#
# [135 rows x 8 columns]

# %% [markdown]
# As the Neighbourhood count did not match to that of earlier data set, also when cross-confirmed with the crime data, 158 neighbourhood count was considered and this data set dropped.

# %%
from geopy.geocoders import Nominatim
import time

# Initialize the geolocator
geolocator = Nominatim(user_agent="neighbourhood_locator")

def get_postal_code(neighbourhood_name):
    try:
        location = geolocator.geocode(f"{neighbourhood_name}, Toronto, Ontario")
        if location:
            # Reverse geocode to get postal code
            postal_location = geolocator.reverse((location.latitude, location.longitude), addressdetails=True)
            postal_code = postal_location.raw['address'].get('postcode', 'Postal code not found')
            return postal_code
    except Exception as e:
        print(f"Error retrieving postal code for {neighbourhood_name}: {e}")
    return None

# Example usage
neighbourhoods = filtered_df_transposed.columns.values


results = []

# Iterate through neighborhoods and get postal codes
for neighbourhood in neighbourhoods:
    postal_code = get_postal_code(neighbourhood)
    print(f"{neighbourhood}: {postal_code}")
    results.append({"Neighbourhood": neighbourhood, "Postal_Code": postal_code})
    time.sleep(1)  # To prevent overloading the server with requests

# Create a DataFrame from the results
df_postal_codes = pd.DataFrame(results)

# Display the DataFrame
(df_postal_codes)
# Out:
# Neighbourhood Name: None
# West Humber-Clairville: M9W 1R9
# Mount Olive-Silverstone-Jamestown: None
# Thistletown-Beaumond Heights: None
# Rexdale-Kipling: M9W 1Y4
# Elms-Old Rexdale: None
# Kingsview Village-The Westway: None
# Willowridge-Martingrove-Richview: None
# Humber Heights-Westmount: M9P 3W3
# Edenbridge-Humber Valley: M9A 3E1
# Princess-Rosethorn: None
# Eringate-Centennial-West Deane: None
# Markland Wood: M9C 2P7
# Etobicoke West Mall: M9C 5S1
# Kingsway South: M6S
# Stonegate-Queensway: M8Z 1N7
# New Toronto: M8V 3B5
# Long Branch: M8W 3T4
# Alderwood: M8W 3T7
# Humber Summit: M9L 2K5
# Humbermede: M9M 2A8
# Pelmo Park-Humberlea: None
# Black Creek: M6M 5E6
# Glenfield-Jane Heights: None
# York University Heights: M3J 1V6
# Rustic: M6L 1N4
# Maple Leaf: M6L 1M8
# Brookhaven-Amesbury: None
# Yorkdale-Glen Park: M6B 3L3
# Englemount-Lawrence: M6B 2H5
# Clanton Park: M3H 3N4
# Bathurst Manor: M3H 2T5
# Westminster-Branson: None
# Newtonbrook West: None
# Willowdale West: M2N 6K9
# Lansing-Westgate: None
# Bedford Park-Nortown: None
# St.Andrew-Windfields: None
# Bridle Path-Sunnybrook-York Mills: None
# Banbury-Don Mills: M2L 2V3
# Victoria Village: M4A 2B1
# Flemingdon Park: M3C 1C3
# Pleasant View: M2J 3Y8
# Don Valley Village: M2J 4X9
# Hillcrest Village: M2H 1M1
# Bayview Woods-Steeles: M2H 1A8
# Newtonbrook East: None
# Bayview Village: M2K 1E6
# Henry Farm: M2J 1H5
# O`Connor Parkview: M4B 2S6
# Thorncliffe Park: M4H 1K3
# Leaside-Bennington: M4G 3A1
# Broadview North: M4K 2R6
# Old East York: M4E 1E5
# Danforth-East York: M4C 1M6
# Woodbine-Lumsden: None
# Taylor Massey: M1J 2P7
# East End Danforth: M4M 3C9
# The Beaches: M4E 1C9
# Woodbine Corridor: None
# Greenwood-Coxwell: None
# Danforth: M4C 4X4
# Playter Estates-Danforth: M4K 2P9
# North Riverdale: M4K 1N6
# Blake-Jones: M4J 3C9
# South Riverdale: M4M 2G3
# Cabbagetown-South St. James Town: None
# Regent Park: M5A 3H6
# Moss Park: M5A 3S5
# North St. James Town: None
# Kensington-Chinatown: None
# University: M5S 2C6
# Palmerston-Little Italy: M6J 1V3
# Trinity-Bellwoods: M6J 2W5
# Dufferin Grove: M6H 1A6
# Little Portugal: M6K 1R3
# South Parkdale: None
# Roncesvalles: M6R 2M3
# High Park-Swansea: M6P
# High Park North: M6P 2W9
# Runnymede-Bloor West Village: M6S
# Junction Area: None
# Weston-Pelham Park: None
# Corso Italia-Davenport: M6E 1B5
# Wychwood: M6C 1A6
# Annex: M5R 2X3
# Casa Loma: M5R 1X9
# Yonge-St. Clair: M4T 1K2
# Rosedale-Moore Park: M4W 1R1
# Mount Pleasant East: M4P 1L1
# Yonge-Eglinton: M4S 2B1
# Forest Hill South: None
# Forest Hill North: M6B 1A6
# Lawrence Park South: None
# Lawrence Park North: M3C 2N2
# Humewood-Cedarvale: M6C 2X4
# Oakwood Village: M6E 2W3
# Briar Hill-Belgravia: M6B 4J3
# Caledonia-Fairbank: M6E 2K3
# Keelesdale-Eglinton West: M6M 1T9
# Rockcliffe-Smythe: M6N
# Beechborough-Greenbrook: None
# Weston: M9N 2E8
# Lambton Baby Point: M6S
# Mount Dennis: M6M 5C4
# Steeles: M1W 3M9
# Tam O'Shanter-Sullivan: None
# Wexford/Maryvale: None
# Clairlea-Birchmount: None
# Oakridge: M1L 3W5
# Birchcliffe-Cliffside: None
# Cliffcrest: M1M 1N3
# Kennedy Park: M1K 2A7
# Ionview: M1K 2Z9
# Dorset Park: M1P 1M2
# Agincourt South-Malvern West: None
# Agincourt North: M1V 1V2
# Milliken: M1V 2G8
# Centennial Scarborough: M1C 2A2
# Highland Creek: M1C 4Y1
# Morningside: M1E 5E1
# West Hill: M1E 2N7
# Eglinton East: M1L 2M6
# Scarborough Village: M1J 3M5
# Guildwood: M1E 1L8
# Golfdale-Cedarbrae-Woburn: None
# Woburn North: M5M 4K1
# West Rouge: M1C 3L6
# Morningside Heights: M1X 1W2
# Malvern West: M1S 3V8
# Malvern East: M1R 0B1
# L'Amoreaux West: None
# East L'Amoreaux: None
# Parkwoods-O'Connor Hills: None
# Fenside-Parkwoods: M3A 1Z5
# Yonge-Doris: None
# East Willowdale: M2N 5W9
# Avondale: M2N 7C3
# Oakdale-Beverley Heights: None
# Downsview: M3H 5R2
# Bendale-Glen Andrew: None
# Bendale South: None
# Islington: M8X 1Y9
# Etobicoke City Centre: M9A 3N5
# Mimico-Queensway: None
# Humber Bay Shores: M8V 1A2
# West Queen West: M6J 1G6
# Fort York-Liberty Village: M6K 1X9
# Wellington Place: None
# Harbourfront-CityPlace: M5V 3A6
# St Lawrence-East Bayfront-The Islands: None
# Church-Wellesley: M4Y 2C7
# Downtown Yonge East: M5C 2T6
# Bay-Cloverhill: None
# Yonge-Bay Corridor: None
# Junction-Wallace Emerson: None
# Dovercourt Village: M6H 3L8
# North Toronto: M5V 3C7
# South Eglinton-Davisville: None
#                          Neighbourhood Postal_Code
# 0                   Neighbourhood Name        None
# 1               West Humber-Clairville     M9W 1R9
# 2    Mount Olive-Silverstone-Jamestown        None
# 3         Thistletown-Beaumond Heights        None
# 4                      Rexdale-Kipling     M9W 1Y4
# ..                                 ...         ...
# 154                 Yonge-Bay Corridor        None
# 155           Junction-Wallace Emerson        None
# 156                 Dovercourt Village     M6H 3L8
# 157                      North Toronto     M5V 3C7
# 158          South Eglinton-Davisville        None
#
# [159 rows x 2 columns]

# %%
# Remove rows with None or 'Postal code not found' as postal code
df1_postal_codes = df_postal_codes[df_postal_codes['Postal_Code'].notna() & (df_postal_codes['Postal_Code'] != 'Postal code not found')]

# Create a new column with the part of the postal code before the first space
df1_postal_codes['Postal'] = df1_postal_codes['Postal_Code'].apply(lambda x: x.split()[0] if isinstance(x, str) else '')
df1_postal_codes = df1_postal_codes.reset_index(drop=True)
# Display the final DataFrame
(df1_postal_codes)
# Out:
#                 Neighbourhood Postal_Code Postal
# 0      West Humber-Clairville     M9W 1R9    M9W
# 1             Rexdale-Kipling     M9W 1Y4    M9W
# 2    Humber Heights-Westmount     M9P 3W3    M9P
# 3    Edenbridge-Humber Valley     M9A 3E1    M9A
# 4               Markland Wood     M9C 2P7    M9C
# ..                        ...         ...    ...
# 104    Harbourfront-CityPlace     M5V 3A6    M5V
# 105          Church-Wellesley     M4Y 2C7    M4Y
# 106       Downtown Yonge East     M5C 2T6    M5C
# 107        Dovercourt Village     M6H 3L8    M6H
# 108             North Toronto     M5V 3C7    M5V
#
# [109 rows x 3 columns]
